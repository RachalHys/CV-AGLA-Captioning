# %%
# !python eval/run_llava.py \
    --image-folder AMBER/image \
    --question-file AMBER/generative.jsonl \
    --answers-file AMBER/output2.jsonl \
    --precision bf16 \
    --use_agla \
    --use-dynamic-alpha \
    --alpha 1.0 \
    --alpha-min 0.5 \
    --beta 0.5 \
    --yolo-conf 0.15 \
    --expansion-ratio 0.0 \
    2>&1 | tee run_log_llava.txt
# Out:
# /home/rachal/projects/CV-AGLA-Improvement/.venv/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /home/rachal/projects/CV-AGLA-Improvement/.venv/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Using Single-GPU Mode
# ⚙️ Loading model with precision: BF16
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.23s/it]
# Loading BLIP Inventory Detector and YOLO-SAM Augmenter...
# Loading BLIP VQA on cuda:0...
# BLIP Inventory Detector Ready!
# Loading YOLO-World on cuda:0...
# Loading MobileSAM on cuda:0...
# YoloSam Augmenter Ready!
# ...

# %%
# %cd /home/rachal/projects/CV-AGLA-Improvement/AMBER

# Convert format
# !python convert_amber_eval.py --input output2.jsonl --output eval2.json

# Evaluate
# !python inference.py --inference_data eval2.json --evaluation_type g --top_k 100
# Out:
# /home/rachal/projects/CV-AGLA-Improvement/AMBER
# Done. Processed 100 items -> eval2.json
# /home/rachal/projects/CV-AGLA-Improvement/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# 100%|█████████████████████████████████████████| 100/100 [00:23<00:00,  4.17it/s]
#
# Saved TOP-100 worst images into 'error_images.json'
# Generative Task:
# CHAIR:           18.7
# Cover:           45.0
# Hal:             74.0
# Cog:             7.5
#
# Results saved to 'result.txt'
